# %% [markdown]
# ### RULE

# %% [markdown]
# 第 3 列更大时，第 9 列也更大

# %% [markdown]
# ### 训练信息

# %%
# 训练信息
rule_model_train_time      = "3h25min"
log_path                   = "/Users/luminshen/Desktop/模型/rule model/T-3>9>/events.out.tfevents.1620142647.luminshendeMacBook-Pro.local"          
model_path                 = "/Users/luminshen/Desktop/模型/rule model/T-3>9>/Ticket_500_7_7"
train_data_path            = "/Users/luminshen/Desktop/模型/rule model/T-3>9>/traindata"

gan_train_time             = "8h"
gan_path                   = "/Users/luminshen/Desktop/模型/new gan/T-3>9>"

# %% [markdown]
# ### 全局参数

# %%
COL_1 = 3
COL_2 = 9

# %% [markdown]
# ### GT 中的 error rate

# %%
import numpy as np
import pandas as pd

GROUND_TRUTH_PATH = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/data/Ticket/Ticket.csv"

def verify_ground_truth_rule():
    file = list(np.array(pd.read_csv(GROUND_TRUTH_PATH, sep=',')))
    col_1 = COL_1
    col_2 = COL_2
    count = 0
    error_list = []
    for i, _ in enumerate(file):
        isOk = True
        t = 0
        for j, _ in enumerate(file):
            if file[i][col_1] > file[j][col_1] and file[i][col_2] > file[j][col_2]:
                error_list.append((i+2, j+2))
                t -= 1
                if t < 0:
                    isOk = False
                    count += 1
                    break
    print("error: {}, error rate:{}".format(count, count / len(file)))
    return count

error_GT = verify_ground_truth_rule()
# Out:
# error: 862, error rate:0.431

# %% [markdown]
# ### 给数据添加标签

# %%
X_OUTPUT = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/data/Ticket/Ticket_rulemodel.csv"
Y_OUTPUT = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/data/Ticket/Ticket_rulemodel_labels.csv"

def generate_data():
    file = list(np.array(pd.read_csv(GROUND_TRUTH_PATH, sep=',')))
    positive = []
    labels = []
    negative = []
    col_1 = COL_1
    col_2 = COL_2
    error = 0
    for i, _ in enumerate(file):
        isOK = True
        for j, _ in enumerate(file):
            if file[i][col_1] > file[j][col_1] and file[i][col_2] > file[j][col_2]:
                negative.append(file[i])
                labels.append([1])
                error += 1
                isOK = False
                break
        if isOK:
            positive.append(file[i])
            labels.append([0])

    X = np.array(positive + negative)
    y = np.array(labels)
    X_out = pd.DataFrame(X)
    y_out = pd.DataFrame(y)
    X_out.to_csv(X_OUTPUT, index=False, sep=',')
    y_out.to_csv(Y_OUTPUT, index=False, sep=',')
    print("输出完成！Xshape:{}, yshape:{} error: {}, error rate:{}".format(X.shape, y.shape, error, error / len(X)))
    return error

error_GD = generate_data()
# Out:
# 输出完成！Xshape:(2000, 14), yshape:(2000, 1) error: 862, error rate:0.431

# %%
assert(error_GT == error_GD)

# %% [markdown]
# ### 验证 Fake Data

# %%
# >, >
OUTPUT_TMP_PATH = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/samples/Ticket/Ticket_OI_11_00_fake.csv"
OUTPUT_PATH = ""
ORIGINAL_PATH = "/Users/luminshen/Desktop/模型/original gan/Ticket/Ticket_OI_11_00_fake.csv"

def verify_rule(path, ratio, c1, c2, name):
    if ratio == -1:
        file = list(np.array(pd.read_csv(path, sep=',')))
    else:
        file = list(np.array(pd.read_csv(path, sep=';')))
    col_1 = c1
    col_2 = c2
    count = 0
    error_list = []
    for i, _ in enumerate(file):
        isOk = True
        t = 0
        for j, _ in enumerate(file):
            if file[i][col_1] > file[j][col_1] and file[i][col_2] > file[j][col_2]:
                t -= 1
                if t < 0:
                    count += 1

    error_rate = count / len(file)**2
    if ratio == -1:
        print("ground truth: error: {:8.0f}, error rate:{:8.6f}".format(count, count / len(file)**2))
        return count / len(file)**2    
    
    else:    
        if error_rate - ratio > 0:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:+{:8.6f}".format(name, count, error_rate, error_rate - ratio))
        else:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:{:8.6f}".format(name, count, error_rate, error_rate - ratio))

        return error_rate - ratio, count


ratio = verify_rule(GROUND_TRUTH_PATH, -1, 0, 9, "")
verify_rule(OUTPUT_TMP_PATH, ratio, 0, 9, "fake")
verify_rule(ORIGINAL_PATH, ratio, 0, 9, "original")
print("------------------------------------------------")

count_fake = 0
count_original = 0
sum_fake = 0
sum_original = 0

for c1 in range(10):
    for c2 in range(10):
        if c1 == c2:
            continue
        ratio = verify_rule(GROUND_TRUTH_PATH, -1, c1, c2 , "")
        diff_fake, error_new = verify_rule(OUTPUT_TMP_PATH, ratio, c1, c2, "fake")
        diff_original, error_original = verify_rule(ORIGINAL_PATH, ratio, c1, c2, "original")
        sum_fake += abs(error_new)
        sum_original += abs(error_original)
        if abs(diff_fake) > abs(diff_original):
            count_original += 1
        else:
            count_fake += 1
        print("------------------------------------------------ {}:{}".format(count_fake, count_original))

print("fake: {}, original: {}, ratio: {}, fake_diff: {}. original_diff: {}".format(count_fake, count_original, count_fake/count_original, sum_fake, sum_original))
# Out:
# ground truth: error:   460476, error rate:0.115119
# fake        : error:   405529, error rate:0.101382, diff:-0.013737
# original    : error:        0, error rate:0.000000, diff:-0.115119
# ------------------------------------------------
# ground truth: error:  1130253, error rate:0.282563
# fake        : error:  1222664, error rate:0.305666, diff:+0.023103
# original    : error:  1155810, error rate:0.288953, diff:+0.006389
# ------------------------------------------------ 0:1
# ground truth: error:  1130253, error rate:0.282563
# fake        : error:   991020, error rate:0.247755, diff:-0.034808
# original    : error:  1130966, error rate:0.282741, diff:+0.000178
# ------------------------------------------------ 0:2
# ground truth: error:   807720, error rate:0.201930
# fake        : error:   177263, error rate:0.044316, diff:-0.157614
# original    : error:   588467, error rate:0.147117, diff:-0.054813
# ------------------------------------------------ 0:3
# ground truth: error:   852318, error rate:0.213080
# fake        : error:   817036, error rate:0.204259, diff:-0.008821
# original    : error:   736491, error rate:0.184123, diff:-0.028957
# ------------------------------------------------ 1:3
# ground truth: error:   852318, error rate:0.213080
# fake        : error:   867844, error rate:0.216961, diff:+0.003881
# original    : error:   839263, error rate:0.209816, diff:-0.003264
# ------------------------------------------------ 1:4
# ground truth: error:   758870, error rate:0.189718
# fake        : error:   761615, error rate:0.190404, diff:+0.000686
# original    : error:   753187, error rate:0.188297, diff:-0.001421
# ------------------------------------------------ 2:4
# ground truth: error:   987961, error rate:0.246990
# fake        : error:  1353939, error rate:0.338485, diff:+0.091495
# original    : error:   889287, error rate:0.222322, diff:-0.024668
# ------------------------------------------------ 2:5
# ground truth: error:  1003457, error rate:0.250864
# fake        : error:  1045966, error rate:0.261491, diff:+0.010627
# original    : error:  1399011, error rate:0.349753, diff:+0.098888
# ------------------------------------------------ 3:5
# ground truth: error:   460476, error rate:0.115119
# fake        : error:   405529, error rate:0.101382, diff:-0.013737
# original    : error:        0, error rate:0.000000, diff:-0.115119
# ------------------------------------------------ 4:5
# ground truth: error:  1130253, error rate:0.282563
# fake        : error:  1222664, error rate:0.305666, diff:+0.023103
# original    : error:  1155810, error rate:0.288953, diff:+0.006389
# ------------------------------------------------ 4:6
# ground truth: error:  1763357, error rate:0.440839
# fake        : error:  1158470, error rate:0.289618, diff:-0.151222
# original    : error:  1629303, error rate:0.407326, diff:-0.033514
# ------------------------------------------------ 4:7
# ground truth: error:   750662, error rate:0.187666
# fake        : error:   574445, error rate:0.143611, diff:-0.044054
# original    : error:  1133660, error rate:0.283415, diff:+0.095749
# ------------------------------------------------ 5:7
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   528490, error rate:0.132123, diff:-0.073869
# original    : error:   810368, error rate:0.202592, diff:-0.003399
# ------------------------------------------------ 5:8
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   536076, error rate:0.134019, diff:-0.071972
# original    : error:   526032, error rate:0.131508, diff:-0.074483
# ------------------------------------------------ 6:8
# ground truth: error:   739057, error rate:0.184764
# fake        : error:  1102779, error rate:0.275695, diff:+0.090930
# original    : error:   381161, error rate:0.095290, diff:-0.089474
# ------------------------------------------------ 6:9
# ground truth: error:  1112127, error rate:0.278032
# fake        : error:   862802, error rate:0.215700, diff:-0.062331
# original    : error:  1316743, error rate:0.329186, diff:+0.051154
# ------------------------------------------------ 6:10
# ground truth: error:  1189927, error rate:0.297482
# fake        : error:   776101, error rate:0.194025, diff:-0.103456
# original    : error:  1465177, error rate:0.366294, diff:+0.068812
# ------------------------------------------------ 6:11
# ground truth: error:   433786, error rate:0.108447
# fake        : error:   428289, error rate:0.107072, diff:-0.001374
# original    : error:        0, error rate:0.000000, diff:-0.108447
# ------------------------------------------------ 7:11
# ground truth: error:  1130253, error rate:0.282563
# fake        : error:   991020, error rate:0.247755, diff:-0.034808
# original    : error:  1130966, error rate:0.282741, diff:+0.000178
# ------------------------------------------------ 7:12
# ground truth: error:  1763357, error rate:0.440839
# fake        : error:  1158470, error rate:0.289618, diff:-0.151222
# original    : error:  1629303, error rate:0.407326, diff:-0.033514
# ------------------------------------------------ 7:13
# ground truth: error:   750662, error rate:0.187666
# fake        : error:   984298, error rate:0.246075, diff:+0.058409
# original    : error:  1177944, error rate:0.294486, diff:+0.106821
# ------------------------------------------------ 8:13
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   808305, error rate:0.202076, diff:-0.003915
# original    : error:  1001969, error rate:0.250492, diff:+0.044501
# ------------------------------------------------ 9:13
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   964300, error rate:0.241075, diff:+0.035084
# original    : error:   735885, error rate:0.183971, diff:-0.022020
# ------------------------------------------------ 9:14
# ground truth: error:   739057, error rate:0.184764
# fake        : error:  1281607, error rate:0.320402, diff:+0.135637
# original    : error:   589403, error rate:0.147351, diff:-0.037413
# ------------------------------------------------ 9:15
# ground truth: error:  1112127, error rate:0.278032
# fake        : error:   644608, error rate:0.161152, diff:-0.116880
# original    : error:  1355536, error rate:0.338884, diff:+0.060852
# ------------------------------------------------ 9:16
# ground truth: error:  1189927, error rate:0.297482
# fake        : error:   691059, error rate:0.172765, diff:-0.124717
# original    : error:  1480238, error rate:0.370059, diff:+0.072578
# ------------------------------------------------ 9:17
# ground truth: error:   433786, error rate:0.108447
# fake        : error:    75398, error rate:0.018850, diff:-0.089597
# original    : error:        0, error rate:0.000000, diff:-0.108447
# ------------------------------------------------ 10:17
# ground truth: error:   807720, error rate:0.201930
# fake        : error:   177263, error rate:0.044316, diff:-0.157614
# original    : error:   588467, error rate:0.147117, diff:-0.054813
# ------------------------------------------------ 10:18
# ground truth: error:   750662, error rate:0.187666
# fake        : error:   574445, error rate:0.143611, diff:-0.044054
# original    : error:  1133660, error rate:0.283415, diff:+0.095749
# ------------------------------------------------ 11:18
# ground truth: error:   750662, error rate:0.187666
# fake        : error:   984298, error rate:0.246075, diff:+0.058409
# original    : error:  1177944, error rate:0.294486, diff:+0.106821
# ------------------------------------------------ 12:18
# ground truth: error:   868159, error rate:0.217040
# fake        : error:   688736, error rate:0.172184, diff:-0.044856
# original    : error:  1456747, error rate:0.364187, diff:+0.147147
# ------------------------------------------------ 13:18
# ground truth: error:   868159, error rate:0.217040
# fake        : error:   676519, error rate:0.169130, diff:-0.047910
# original    : error:   699573, error rate:0.174893, diff:-0.042147
# ------------------------------------------------ 13:19
# ground truth: error:   901590, error rate:0.225398
# fake        : error:   935652, error rate:0.233913, diff:+0.008516
# original    : error:   677867, error rate:0.169467, diff:-0.055931
# ------------------------------------------------ 14:19
# ground truth: error:   588844, error rate:0.147211
# fake        : error:   402245, error rate:0.100561, diff:-0.046650
# original    : error:  1639148, error rate:0.409787, diff:+0.262576
# ------------------------------------------------ 15:19
# ground truth: error:   570668, error rate:0.142667
# fake        : error:   821354, error rate:0.205339, diff:+0.062672
# original    : error:  1128850, error rate:0.282212, diff:+0.139545
# ------------------------------------------------ 16:19
# ground truth: error:   446198, error rate:0.111549
# fake        : error:     1992, error rate:0.000498, diff:-0.111051
# original    : error:        0, error rate:0.000000, diff:-0.111549
# ------------------------------------------------ 17:19
# ground truth: error:   852318, error rate:0.213080
# fake        : error:   817036, error rate:0.204259, diff:-0.008821
# original    : error:   736491, error rate:0.184123, diff:-0.028957
# ------------------------------------------------ 18:19
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   528490, error rate:0.132123, diff:-0.073869
# original    : error:   810368, error rate:0.202592, diff:-0.003399
# ------------------------------------------------ 18:20
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   808305, error rate:0.202076, diff:-0.003915
# original    : error:  1001969, error rate:0.250492, diff:+0.044501
# ------------------------------------------------ 19:20
# ground truth: error:   868159, error rate:0.217040
# fake        : error:   688736, error rate:0.172184, diff:-0.044856
# original    : error:  1456747, error rate:0.364187, diff:+0.147147
# ------------------------------------------------ 20:20
# ground truth: error:  1916296, error rate:0.479074
# fake        : error:  1694855, error rate:0.423714, diff:-0.055360
# original    : error:  1017751, error rate:0.254438, diff:-0.224636
# ------------------------------------------------ 21:20
# ground truth: error:   942361, error rate:0.235590
# fake        : error:  1212252, error rate:0.303063, diff:+0.067473
# original    : error:   999376, error rate:0.249844, diff:+0.014254
# ------------------------------------------------ 21:21
# ground truth: error:  1086730, error rate:0.271682
# fake        : error:   946347, error rate:0.236587, diff:-0.035096
# original    : error:  1419297, error rate:0.354824, diff:+0.083142
# ------------------------------------------------ 22:21
# ground truth: error:  1014371, error rate:0.253593
# fake        : error:   542667, error rate:0.135667, diff:-0.117926
# original    : error:  1098882, error rate:0.274720, diff:+0.021128
# ------------------------------------------------ 22:22
# ground truth: error:   556956, error rate:0.139239
# fake        : error:     7317, error rate:0.001829, diff:-0.137410
# original    : error:        0, error rate:0.000000, diff:-0.139239
# ------------------------------------------------ 23:22
# ground truth: error:   852318, error rate:0.213080
# fake        : error:   867844, error rate:0.216961, diff:+0.003881
# original    : error:   839263, error rate:0.209816, diff:-0.003264
# ------------------------------------------------ 23:23
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   536076, error rate:0.134019, diff:-0.071972
# original    : error:   526032, error rate:0.131508, diff:-0.074483
# ------------------------------------------------ 24:23
# ground truth: error:   823965, error rate:0.205991
# fake        : error:   964300, error rate:0.241075, diff:+0.035084
# original    : error:   735885, error rate:0.183971, diff:-0.022020
# ------------------------------------------------ 24:24
# ground truth: error:   868159, error rate:0.217040
# fake        : error:   676519, error rate:0.169130, diff:-0.047910
# original    : error:   699573, error rate:0.174893, diff:-0.042147
# ------------------------------------------------ 24:25
# ground truth: error:  1916296, error rate:0.479074
# fake        : error:  1694855, error rate:0.423714, diff:-0.055360
# original    : error:  1017751, error rate:0.254438, diff:-0.224636
# ------------------------------------------------ 25:25
# ground truth: error:   942361, error rate:0.235590
# fake        : error:  1236931, error rate:0.309233, diff:+0.073642
# original    : error:  1763305, error rate:0.440826, diff:+0.205236
# ------------------------------------------------ 26:25
# ground truth: error:  1086730, error rate:0.271682
# fake        : error:   830963, error rate:0.207741, diff:-0.063942
# original    : error:   633420, error rate:0.158355, diff:-0.113327
# ------------------------------------------------ 27:25
# ground truth: error:  1014371, error rate:0.253593
# fake        : error:   556402, error rate:0.139100, diff:-0.114492
# original    : error:   687855, error rate:0.171964, diff:-0.081629
# ------------------------------------------------ 27:26
# ground truth: error:   556956, error rate:0.139239
# fake        : error:     2475, error rate:0.000619, diff:-0.138620
# original    : error:        0, error rate:0.000000, diff:-0.139239
# ------------------------------------------------ 28:26
# ground truth: error:   758870, error rate:0.189718
# fake        : error:   761615, error rate:0.190404, diff:+0.000686
# original    : error:   753187, error rate:0.188297, diff:-0.001421
# ------------------------------------------------ 29:26
# ground truth: error:   739057, error rate:0.184764
# fake        : error:  1102779, error rate:0.275695, diff:+0.090930
# original    : error:   381161, error rate:0.095290, diff:-0.089474
# ------------------------------------------------ 29:27
# ground truth: error:   739057, error rate:0.184764
# fake        : error:  1281607, error rate:0.320402, diff:+0.135637
# original    : error:   589403, error rate:0.147351, diff:-0.037413
# ------------------------------------------------ 29:28
# ground truth: error:   901590, error rate:0.225398
# fake        : error:   935652, error rate:0.233913, diff:+0.008516
# original    : error:   677867, error rate:0.169467, diff:-0.055931
# ------------------------------------------------ 30:28
# ground truth: error:   942361, error rate:0.235590
# fake        : error:  1212252, error rate:0.303063, diff:+0.067473
# original    : error:   999376, error rate:0.249844, diff:+0.014254
# ------------------------------------------------ 30:29
# ground truth: error:   942361, error rate:0.235590
# fake        : error:  1236931, error rate:0.309233, diff:+0.073642
# original    : error:  1763305, error rate:0.440826, diff:+0.205236
# ------------------------------------------------ 31:29
# ground truth: error:   703387, error rate:0.175847
# fake        : error:   339724, error rate:0.084931, diff:-0.090916
# original    : error:   588162, error rate:0.147040, diff:-0.028806
# ------------------------------------------------ 31:30
# ground truth: error:   591341, error rate:0.147835
# fake        : error:   199866, error rate:0.049966, diff:-0.097869
# original    : error:   553738, error rate:0.138434, diff:-0.009401
# ------------------------------------------------ 31:31
# ground truth: error:   477798, error rate:0.119450
# fake        : error:       20, error rate:0.000005, diff:-0.119444
# original    : error:        0, error rate:0.000000, diff:-0.119450
# ------------------------------------------------ 32:31
# ground truth: error:   987961, error rate:0.246990
# fake        : error:  1353939, error rate:0.338485, diff:+0.091495
# original    : error:   889287, error rate:0.222322, diff:-0.024668
# ------------------------------------------------ 32:32
# ground truth: error:  1112127, error rate:0.278032
# fake        : error:   862802, error rate:0.215700, diff:-0.062331
# original    : error:  1316743, error rate:0.329186, diff:+0.051154
# ------------------------------------------------ 32:33
# ground truth: error:  1112127, error rate:0.278032
# fake        : error:   644608, error rate:0.161152, diff:-0.116880
# original    : error:  1355536, error rate:0.338884, diff:+0.060852
# ------------------------------------------------ 32:34
# ground truth: error:   588844, error rate:0.147211
# fake        : error:   402245, error rate:0.100561, diff:-0.046650
# original    : error:  1639148, error rate:0.409787, diff:+0.262576
# ------------------------------------------------ 33:34
# ground truth: error:  1086730, error rate:0.271682
# fake        : error:   946347, error rate:0.236587, diff:-0.035096
# original    : error:  1419297, error rate:0.354824, diff:+0.083142
# ------------------------------------------------ 34:34
# ground truth: error:  1086730, error rate:0.271682
# fake        : error:   830963, error rate:0.207741, diff:-0.063942
# original    : error:   633420, error rate:0.158355, diff:-0.113327
# ------------------------------------------------ 35:34
# ground truth: error:   703387, error rate:0.175847
# fake        : error:   339724, error rate:0.084931, diff:-0.090916
# original    : error:   588162, error rate:0.147040, diff:-0.028806
# ------------------------------------------------ 35:35
# ground truth: error:  1625096, error rate:0.406274
# fake        : error:  1468375, error rate:0.367094, diff:-0.039180
# original    : error:  1425238, error rate:0.356310, diff:-0.049965
# ------------------------------------------------ 36:35
# ground truth: error:   558338, error rate:0.139585
# fake        : error:   465850, error rate:0.116462, diff:-0.023122
# original    : error:        0, error rate:0.000000, diff:-0.139585
# ------------------------------------------------ 37:35
# ground truth: error:  1003457, error rate:0.250864
# fake        : error:  1045966, error rate:0.261491, diff:+0.010627
# original    : error:  1399011, error rate:0.349753, diff:+0.098888
# ------------------------------------------------ 38:35
# ground truth: error:  1189927, error rate:0.297482
# fake        : error:   776101, error rate:0.194025, diff:-0.103456
# original    : error:  1465177, error rate:0.366294, diff:+0.068812
# ------------------------------------------------ 38:36
# ground truth: error:  1189927, error rate:0.297482
# fake        : error:   691059, error rate:0.172765, diff:-0.124717
# original    : error:  1480238, error rate:0.370059, diff:+0.072578
# ------------------------------------------------ 38:37
# ground truth: error:   570668, error rate:0.142667
# fake        : error:   821354, error rate:0.205339, diff:+0.062672
# original    : error:  1128850, error rate:0.282212, diff:+0.139545
# ------------------------------------------------ 39:37
# ground truth: error:  1014371, error rate:0.253593
# fake        : error:   542667, error rate:0.135667, diff:-0.117926
# original    : error:  1098882, error rate:0.274720, diff:+0.021128
# ------------------------------------------------ 39:38
# ground truth: error:  1014371, error rate:0.253593
# fake        : error:   556402, error rate:0.139100, diff:-0.114492
# original    : error:   687855, error rate:0.171964, diff:-0.081629
# ------------------------------------------------ 39:39
# ground truth: error:   591341, error rate:0.147835
# fake        : error:   199866, error rate:0.049966, diff:-0.097869
# original    : error:   553738, error rate:0.138434, diff:-0.009401
# ------------------------------------------------ 39:40
# ground truth: error:  1625096, error rate:0.406274
# fake        : error:  1468375, error rate:0.367094, diff:-0.039180
# original    : error:  1425238, error rate:0.356310, diff:-0.049965
# ------------------------------------------------ 40:40
# ground truth: error:   523730, error rate:0.130933
# fake        : error:   448981, error rate:0.112245, diff:-0.018687
# original    : error:        0, error rate:0.000000, diff:-0.130933
# ------------------------------------------------ 41:40
# ground truth: error:   460476, error rate:0.115119
# fake        : error:   405529, error rate:0.101382, diff:-0.013737
# original    : error:        0, error rate:0.000000, diff:-0.115119
# ------------------------------------------------ 42:40
# ground truth: error:   433786, error rate:0.108447
# fake        : error:   428289, error rate:0.107072, diff:-0.001374
# original    : error:        0, error rate:0.000000, diff:-0.108447
# ------------------------------------------------ 43:40
# ground truth: error:   433786, error rate:0.108447
# fake        : error:    75398, error rate:0.018850, diff:-0.089597
# original    : error:        0, error rate:0.000000, diff:-0.108447
# ------------------------------------------------ 44:40
# ground truth: error:   446198, error rate:0.111549
# fake        : error:     1992, error rate:0.000498, diff:-0.111051
# original    : error:        0, error rate:0.000000, diff:-0.111549
# ------------------------------------------------ 45:40
# ground truth: error:   556956, error rate:0.139239
# fake        : error:     7317, error rate:0.001829, diff:-0.137410
# original    : error:        0, error rate:0.000000, diff:-0.139239
# ------------------------------------------------ 46:40
# ground truth: error:   556956, error rate:0.139239
# fake        : error:     2475, error rate:0.000619, diff:-0.138620
# original    : error:        0, error rate:0.000000, diff:-0.139239
# ------------------------------------------------ 47:40
# ground truth: error:   477798, error rate:0.119450
# fake        : error:       20, error rate:0.000005, diff:-0.119444
# original    : error:        0, error rate:0.000000, diff:-0.119450
# ------------------------------------------------ 48:40
# ground truth: error:   558338, error rate:0.139585
# fake        : error:   465850, error rate:0.116462, diff:-0.023122
# original    : error:        0, error rate:0.000000, diff:-0.139585
# ------------------------------------------------ 49:40
# ground truth: error:   523730, error rate:0.130933
# fake        : error:   448981, error rate:0.112245, diff:-0.018687
# original    : error:        0, error rate:0.000000, diff:-0.130933
# ------------------------------------------------ 50:40
# fake: 50, original: 40, ratio: 1.25, fake_diff: 65078852. original_diff: 73770220

# %%
# =, !=
OUTPUT_TMP_PATH = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/samples/Ticket/Ticket_OI_11_00_fake.csv"
OUTPUT_PATH = ""
ORIGINAL_PATH = "/Users/luminshen/Desktop/模型/original gan/Ticket/Ticket_OI_11_00_fake.csv"

def verify_rule(path, ratio, c1, c2, name):
    if ratio == -1:
        file = list(np.array(pd.read_csv(path, sep=',')))
    else:
        file = list(np.array(pd.read_csv(path, sep=';')))
    col_1 = c1
    col_2 = c2
    count = 0
    error_list = []
    for i, _ in enumerate(file):
        isOk = True
        t = 0
        for j, _ in enumerate(file):
            if file[i][col_1] == file[j][col_1] and file[i][col_2] != file[j][col_2]:
                t -= 1
                if t < 0:
                    count += 1

    error_rate = count / len(file)**2
    if ratio == -1:
        print("ground truth: error: {:8.0f}, error rate:{:8.6f}".format(count, count / len(file)**2))
        return count / len(file)**2    
    
    else:    
        if error_rate - ratio > 0:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:+{:8.6f}".format(name, count, error_rate, error_rate - ratio))
        else:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:{:8.6f}".format(name, count, error_rate, error_rate - ratio))

        return error_rate - ratio, count



ratio = verify_rule(GROUND_TRUTH_PATH, -1, 0, 9, "")
verify_rule(OUTPUT_TMP_PATH, ratio, 0, 9, "fake")
verify_rule(ORIGINAL_PATH, ratio, 0, 9, "original")
print("------------------------------------------------")

count_fake = 0
count_original = 0
sum_fake = 0
sum_original = 0

for c1 in range(10):
    for c2 in range(10):
        if c1 == c2:
            continue
        ratio = verify_rule(GROUND_TRUTH_PATH, -1, c1, c2 , "")
        diff_fake, error_new = verify_rule(OUTPUT_TMP_PATH, ratio, c1, c2, "fake")
        diff_original, error_original = verify_rule(ORIGINAL_PATH, ratio, c1, c2, "original")
        sum_fake += abs(error_new)
        sum_original += abs(error_original)
        if abs(diff_fake) > abs(diff_original):
            count_original += 1
        else:
            count_fake += 1
        print("------------------------------------------------ {}:{}".format(count_fake, count_original))

print("fake: {}, original: {}, ratio: {}, fake_diff: {}. original_diff: {}".format(count_fake, count_original, count_fake/count_original, sum_fake, sum_original))
# Out:
# ground truth: error:   236086, error rate:0.059021
# fake        : error:   106426, error rate:0.026607, diff:-0.032415
# original    : error:        0, error rate:0.000000, diff:-0.059021
# ------------------------------------------------
# ground truth: error:        0, error rate:0.000000
# fake        : error:   305932, error rate:0.076483, diff:+0.076483
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-827bb123a010> in <module>
#      51             continue
#      52         ratio = verify_rule(GROUND_TRUTH_PATH, -1, c1, c2 , "")
# ---> 53         diff_fake, error_new = verify_rule(OUTPUT_TMP_PATH, ratio, c1, c2, "fake")
#      54         diff_original, error_original = verify_rule(ORIGINAL_PATH, ratio, c1, c2, "original")
#      55         sum_fake += abs(error_new)
#
# TypeError: cannot unpack non-iterable float object

# %%
# >, !=
OUTPUT_TMP_PATH = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/samples/Ticket/Ticket_OI_11_00_fake.csv"
OUTPUT_PATH = ""
ORIGINAL_PATH = "/Users/luminshen/Desktop/模型/original gan/Ticket/Ticket_OI_11_00_fake.csv"

def verify_rule(path, ratio, c1, c2, name):
    if ratio == -1:
        file = list(np.array(pd.read_csv(path, sep=',')))
    else:
        file = list(np.array(pd.read_csv(path, sep=';')))
    col_1 = c1
    col_2 = c2
    count = 0
    error_list = []
    for i, _ in enumerate(file):
        isOk = True
        t = 0
        for j, _ in enumerate(file):
            if file[i][col_1] > file[j][col_1] and file[i][col_2] != file[j][col_2]:
                t -= 1
                if t < 0:
                    count += 1

    error_rate = count / len(file)**2
    if ratio == -1:
        print("ground truth: error: {:8.0f}, error rate:{:8.6f}".format(count, count / len(file)**2))
        return count / len(file)**2    
    
    else:    
        if error_rate - ratio > 0:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:+{:8.6f}".format(name, count, error_rate, error_rate - ratio))
        else:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:{:8.6f}".format(name, count, error_rate, error_rate - ratio))

        return error_rate - ratio, count



ratio = verify_rule(GROUND_TRUTH_PATH, -1, 0, 9, "")
verify_rule(OUTPUT_TMP_PATH, ratio, 0, 9, "fake")
verify_rule(ORIGINAL_PATH, ratio, 0, 9, "original")
print("------------------------------------------------")

count_fake = 0
count_original = 0
sum_fake = 0
sum_original = 0

for c1 in range(10):
    for c2 in range(10):
        if c1 == c2:
            continue
        ratio = verify_rule(GROUND_TRUTH_PATH, -1, c1, c2 , "")
        diff_fake, error_new = verify_rule(OUTPUT_TMP_PATH, ratio, c1, c2, "fake")
        diff_original, error_original = verify_rule(ORIGINAL_PATH, ratio, c1, c2, "original")
        sum_fake += abs(error_new)
        sum_original += abs(error_original)
        if abs(diff_fake) > abs(diff_original):
            count_original += 1
        else:
            count_fake += 1
        print("------------------------------------------------ {}:{}".format(count_fake, count_original))

print("fake: {}, original: {}, ratio: {}, fake_diff: {}. original_diff: {}".format(count_fake, count_original, count_fake/count_original, sum_fake, sum_original))

# %%
# >, !=
OUTPUT_TMP_PATH = "/Users/luminshen/Documents/代码/PycharmProjects/Research/-GAN-/Table-GAN/tableGAN/samples/Ticket/Ticket_OI_11_00_fake.csv"
OUTPUT_PATH = ""
ORIGINAL_PATH = "/Users/luminshen/Desktop/模型/original gan/Ticket/Ticket_OI_11_00_fake.csv"

def verify_rule(path, ratio, c1, c2, name):
    if ratio == -1:
        file = list(np.array(pd.read_csv(path, sep=',')))
    else:
        file = list(np.array(pd.read_csv(path, sep=';')))
    col_1 = c1
    col_2 = c2
    count = 0
    error_list = []
    for i, _ in enumerate(file):
        isOk = True
        t = 0
        for j, _ in enumerate(file):
            if file[i][col_1] > file[j][col_1] and file[i][col_2] != file[j][col_2]:
                t -= 1
                if t < 0:
                    count += 1

    error_rate = count / len(file)**2
    if ratio == -1:
        print("ground truth: error: {:8.0f}, error rate:{:8.6f}".format(count, count / len(file)**2))
        return count / len(file)**2    
    
    else:    
        if error_rate - ratio > 0:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:+{:8.6f}".format(name, count, error_rate, error_rate - ratio))
        else:
            print("{:12}: error: {:8.0f}, error rate:{:8.6f}, diff:{:8.6f}".format(name, count, error_rate, error_rate - ratio))

        return error_rate - ratio, count



ratio = verify_rule(GROUND_TRUTH_PATH, -1, 0, 9, "")
verify_rule(OUTPUT_TMP_PATH, ratio, 0, 9, "fake")
verify_rule(ORIGINAL_PATH, ratio, 0, 9, "original")
print("------------------------------------------------")

count_fake = 0
count_original = 0
sum_fake = 0
sum_original = 0

for c1 in range(10):
    for c2 in range(10):
        if c1 == c2:
            continue
        ratio = verify_rule(GROUND_TRUTH_PATH, -1, c1, c2 , "")
        diff_fake, error_new = verify_rule(OUTPUT_TMP_PATH, ratio, c1, c2, "fake")
        diff_original, error_original = verify_rule(ORIGINAL_PATH, ratio, c1, c2, "original")
        sum_fake += abs(error_new)
        sum_original += abs(error_original)
        if abs(diff_fake) > abs(diff_original):
            count_original += 1
        else:
            count_fake += 1
        print("------------------------------------------------ {}:{}".format(count_fake, count_original))

print("fake: {}, original: {}, ratio: {}, fake_diff: {}. original_diff: {}".format(count_fake, count_original, count_fake/count_original, sum_fake, sum_original))
